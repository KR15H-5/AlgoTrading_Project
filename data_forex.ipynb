# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf

# %%
u2g = pd.read_csv('USDGBP.csv')
g2u = pd.read_csv('GBPUSD.csv')

# %%
g2u
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume
# 0     2010-01-01  1.618202  1.618202  1.613111  1.613294   1.613294     0.0
# 1     2010-01-04  1.613710  1.623904  1.606503  1.611370   1.611370     0.0
# 2     2010-01-05  1.611863  1.615587  1.597010  1.599079   1.599079     0.0
# 3     2010-01-06  1.599360  1.606323  1.594388  1.602384   1.602384     0.0
# 4     2010-01-07  1.602205  1.605858  1.590078  1.593397   1.593397     0.0
# ...          ...       ...       ...       ...       ...        ...     ...
# 3386  2022-12-26  1.206001  1.209614  1.205400  1.206001   1.206001     0.0
# 3387  2022-12-27  1.208357  1.211226  1.200336  1.208415   1.208415     0.0
# 3388  2022-12-28  1.202776  1.212415  1.200336  1.202733   1.202733     0.0
# 3389  2022-12-29  1.203297  1.207584  1.201548  1.202848   1.202848     0.0
# 3390  2022-12-30  1.205662  1.210683  1.201273  1.205633   1.205633     0.0
#
# [3391 rows x 7 columns]

# %%
plt.plot(g2u['Date'], g2u['Adj Close'])

# %%
plt.plot(u2g['Date'], u2g['Adj Close'])

# %%
g2e = yf.download('GBPEUR=X', '2010-01-01', '2023-01-01')
g2e
plt.plot(g2e.index, g2e['Adj Close'])
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
e2g = yf.download('EURGBP=X', '2010-01-01', '2023-01-01')
e2g
plt.plot(e2g.index, e2g['Adj Close'])
# Out:
# [*********************100%%**********************]  1 of 1 completed
