# %% [markdown]
# # NEFS Technology Division - Algorithmic Trading Project Template

# %% [markdown]
# ### Description
#
# As a group, you have been tasked with researching, implementing and testing a profitable Foreign Exchange (Forex) trading strategy. The pair you have been assigned is GBP/USD.
#
# Each group will have a number of Quants, Software Engineers and Product Managers. You will need to work as a team to allocate responsibilities for the duration of the project. e.g. a Product Manager may be incharge of setting up and maintaining the Jira backlog of tickets.
#
# You will be provided with a dataset that will allow you to develop and backtest your strategy. This dataset will provide you with all of the relevant data for a number of years. Your strategy will then be tested on a different timeframe to determine it's profitability (Profit/Loss).
#
# It may be useful to begin the task by trying to understand the 'bigger picture' of how each component of the project would come together i.e the strategy itself, the risk management system, the data and your testing systems.
#
# You will be provided with an initial template to set out the fundamental components of your system, but you can feel free to expand on these as you wish. However, you need to be wary that your strategy **MUST** still be able to be backtested through the function included below. Please **DO NOT** modify this function in any way.
#
# We have seperated your teams to include Analysts of different disciplines, skills and interests. You should capitalise on this to allow everyone to contribute to the project in the best way that they can.
#
# Some example roles you may want to have (you do not have to stick to these) :
#
# - Software Engineer
# - Quant Researcher
# - Quant Developer
# - Algo Engineer
# - Data Scientist
# - Product Manager
#
# Information Links:
#
# - [Investopedia - Forex Trading](https://www.investopedia.com/terms/f/foreign-exchange.asp)
# - [Investopedia - Forex (Definitions, How To and Examples)](https://www.investopedia.com/terms/f/forex.asp)
# - [CME Group British Pound GBP/USD Overview](https://www.cmegroup.com/markets/fx/g10/british-pound.html)
# - [Yahoo Finance GBP/USD Live Charts](https://finance.yahoo.com/quote/GBPUSD=X?p=GBPUSD=X&.tsrc=fin-srch)
# - [Yahoo Finance USD/GBP Live Charts](https://finance.yahoo.com/quote/GBP=X?p=GBP=X&.tsrc=fin-srch)
#
# #### Rules:
#
# Here are some rules to simplify this task.
#
# - You can only buy your positions in GBP and sell your positions in USD.
# - You can not leverage or borrow money to buy a position (no negative balances). If your wallet goes to 0 then something is wrong.
# - You can not sell a position you do not have (no shorting)
# - When selling a position, you must sell all of the lots within that position. You can not off-load part of your position.
#
#
# **What is a standard lot in Forex?**
#
# A standard lot in Forex is equal to **100,000 currency units**. It’s the standard unit size for traders, whether independent or institutional.
#
# If the GBP/USD exchange rate was $1.3000, one standard lot of the base currency (GBP) would be 130,000 units. This means, at the current price, you’d need 130,000 units of the quote currency (USD) to buy 100,000 units of GBP.
#
# ---

# %% [markdown]
# ### Datasets
#
# Under this section you will find that two initial datasets are being loaded to be used for this project. These datasets are:
#
# - GBP/USD Historical Prices between 01/01/2010 - 31/12/2020 (Daily)
# - USD/GBP Historical Prices between 01/01/2010 - 31/12/2020 (Daily)
#
# Through your research, you may also find that other datasets across the internet may prove useful in your strategy e.g. Geopolitical data, other currency pairs etc. Feel free to use such datasets to help improve your strategy if you would like to do so.

# %%
#importing some popular packages that you may find useful

import pandas as pd 
import numpy as np 
import matplotlib as plt
from enum import Enum
from datetime import datetime
import uuid 
import string

# %%
complete_gbp_usd_dataset = pd.read_csv('GBPUSD_2010_2022.csv')
complete_usd_gbp_dataset = pd.read_csv('USDGBP_2010_2022.csv')

complete_gbp_usd_dataset
complete_usd_gbp_dataset
# Out:
#             Date      Open     High      Low     Close  Adj Close  Volume
# 0     2010-01-01  0.617970  0.61992  0.61797  0.619850   0.619850     0.0
# 1     2010-01-04  0.619690  0.62247  0.61580  0.620590   0.620590     0.0
# 2     2010-01-05  0.620400  0.62617  0.61897  0.625360   0.625360     0.0
# 3     2010-01-06  0.625250  0.62720  0.62254  0.624070   0.624070     0.0
# 4     2010-01-07  0.624140  0.62890  0.62272  0.627590   0.627590     0.0
# ...          ...       ...      ...      ...       ...        ...     ...
# 3386  2022-12-26  0.829187  0.82960  0.82671  0.829187   0.829187     0.0
# 3387  2022-12-27  0.827570  0.83310  0.82561  0.827530   0.827530     0.0
# 3388  2022-12-28  0.831410  0.83310  0.82480  0.831440   0.831440     0.0
# 3389  2022-12-29  0.831050  0.83226  0.82810  0.831360   0.831360     0.0
# 3390  2022-12-30  0.829420  0.83245  0.82598  0.829440   0.829440     0.0
#
# [3391 rows x 7 columns]

# %%
data = pd.DataFrame(complete_gbp_usd_dataset)
data['SMA30'] = data['Open'].rolling(30).mean()
open_prices = data['Open']
close_prices = data['Close']
dates = data['Date']
data.dropna(inplace=True)

def get_sma(prices, rate):
    return prices.rolling(rate).mean()
data['SMA20'] = get_sma(close_prices,20)

data

##Mean Reversion
timeframe = 30
threshold_buy = -0.01
threshold_sell= 0.01
data['sma'] = data['Close'].rolling(window=timeframe).mean()
data['percent_distance'] = ((data['Close']-data['sma'])/data['sma'])
data['signal'] = 0
data.loc[data['percent_distance'] <= threshold_buy, 'signal']= 1
data.loc[data['percent_distance'] >= threshold_sell, 'signal']= -1
data
##Volatility
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume  \
# 29    2010-02-11  1.561402  1.571685  1.556590  1.570204   1.570204     0.0
# 30    2010-02-12  1.570204  1.573886  1.558701  1.569809   1.569809     0.0
# 31    2010-02-15  1.567890  1.571907  1.561792  1.566711   1.566711     0.0
# 32    2010-02-16  1.566637  1.579554  1.563257  1.579005   1.579005     0.0
# 33    2010-02-17  1.578906  1.581778  1.566907  1.568209   1.568209     0.0
# ...          ...       ...       ...       ...       ...        ...     ...
# 3386  2022-12-26  1.206001  1.209614  1.205400  1.206001   1.206001     0.0
# 3387  2022-12-27  1.208357  1.211226  1.200336  1.208415   1.208415     0.0
# 3388  2022-12-28  1.202776  1.212415  1.200336  1.202733   1.202733     0.0
# 3389  2022-12-29  1.203297  1.207584  1.201548  1.202848   1.202848     0.0
# 3390  2022-12-30  1.205662  1.210683  1.201273  1.205633   1.205633     0.0
#
#          SMA30     SMA20       sma  percent_distance  signal
# 29    1.605970  1.600863       NaN               NaN       0
# 30    1.604370  1.598004       NaN               NaN       0
# 31    1.602842  1.594575       NaN               NaN       0
# 32    1.601335  1.591742       NaN               NaN       0
# 33    1.600653  1.588662       NaN               NaN       0
# ...        ...       ...       ...               ...     ...
# 3386  1.209123  1.217352  1.209097         -0.002560       0
# 3387  1.210226  1.217971  1.210202         -0.001477       0
# 3388  1.210715  1.218374  1.210692         -0.006574       0
# 3389  1.211095  1.218129  1.211069         -0.006788       0
# 3390  1.211752  1.217114  1.211723         -0.005026       0
#
# [3212 rows x 12 columns]

# %% [markdown]
# ### Portfolio
#
# Under this section you will find the boiler plate code for this task. This includes a class named 'portfolio' which will house key data around your trades such as your budget (monetary portfolio), net profit/loss, current positions and number of trades executed etc.
#
# Each time you run a backtest of your strategy, this object will be reinstatiated and repopulated with the latest backtest results.
#
# You **MUST NOT** modify this code in any way. If you suspect there is a bug, please let us know and we will look into resolving it.

# %% [markdown]
# ## All of the backend code. DO NOT CHANGE THIS SECTION IN ANY WAY.

# %%
INITIAL_WALLET_CASH = 5000000
STANDARD_LOT = 100000

class Side(Enum):
    BUY = 'BUY'
    SELL = 'SELL'
    
class Currency(Enum):
    GBP = 'GBP'
    USD = 'USD'
    
class Position:
    def __init__(self,
                 date:datetime,
                 size:int,
                 price,
                 currency:Currency,
                 side:Side):
        
        self._id = str(uuid.uuid4())
        self._date = date
        self._currency = currency
        self._price = price
        self._size = size
        self._side = side
        
class Order:
    def __init__(self,
                 position:Position):
        self._id = str(uuid.uuid4())
        self._position = position
    
    def describe(self):
        return f"<Order id: {self._id} position: {self._position}>"

class Portfolio:
    
    def __init__(self):
        self.cash_wallet = INITIAL_WALLET_CASH  # wallet is in GBP
        self.current_positions = {}
        self.closed_positions = {}
    
    def add_position(self,position):
        self.current_positions[position._id] = position
        self.deduct_from_wallet(self.calculate_deduction(position))
                
    def sell_position(self,position:Position):
        self.current_positions.pop(position._id)
        self.closed_positions[position._id] = position
    
    def get_wallet_value(self):
        return self.cash_wallet
    
    def deduct_from_wallet(self,amount):
        self.cash_wallet -= amount
        
    def add_to_wallet(self,amount):
        self.cash_wallet += amount
        
    def calculate_fees(self,position:Position):
        fee = position._size * 2 #broker fee is £2 per standard lot 
        print("FEE CHARGED: £",fee)
        return fee 
    
    def calculate_total_cost_in_gbp(self,position:Position):
        if(position._currency == Currency.GBP):
            return position._price * (position._size * STANDARD_LOT)
        # elif(position._currency == Currency.USD):
        #     return position._price * current_gbp_price  * (position._size * 100000) # x100000 for standard lot

    def calculate_deduction(self,position):
        return self.calculate_total_cost_in_gbp(position) + self.calculate_fees(position)

# %% [markdown]
# ## You can edit from this point onwards

# %%
## You can implement your strategy in this function.
## Feel free to create additional functions and call them from within the 'strategy' function
## As show in the example below, your function must return a dictionary of orders. 
## These orders will be run through the backtesting function
def strategy(data):
    
    FIXED_LOT_SIZE = 1
    
    orders = {}
    
    for index,row in data.iterrows():
        date = datetime.strptime(str(row["Date"]),'%Y-%m-%d').date()
        
        if(row['signal'] == 1 and len(orders) <= 500): 
            
            
            #if we have money available in the wallet, we can buy
            buy_position = Position(date,FIXED_LOT_SIZE,row.Open,Currency.GBP,Side.BUY)
            buy_order = Order(buy_position)
            orders[buy_order._id] = buy_order
    
        if(row['signal'] == -1  and len(orders) <= 1000):
            sell_position = Position(date,FIXED_LOT_SIZE,row.Open,Currency.GBP,Side.SELL)
            sell_order = Order(sell_position)
            orders[sell_order._id] = sell_order
        
      
   
    return orders

# %%
# You can use this function to backtest your strategy 
# The function will call your strategy and then execute the orders in the sequence you made them
# Once all of your orders have been completed, you will be shown your final wallet amount and your Profit/Loss.
def local_backtest_strategy(data):
    
    # Initialising the portfolio. £5,000,000 cash and no positions. 
    portfolio = Portfolio()
    order_queue = strategy(data) #calls your function to get all of the orders
    
    for index,order in order_queue.items():
    
        if(order._position._side == Side.BUY):
            # if you have enough cash, you can make the purchase 
            if portfolio.calculate_total_cost_in_gbp(order._position) <= portfolio.cash_wallet:
                portfolio.add_position(order._position)
                print(f"BUY ORDER FILLED : (ID) {str(order._id).upper()}")
            else: 
                print("BOOK CASH IS INSUFFICIENT")
                
        if(order._position._side == Side.SELL):
            # finding the position we want to sell from our current positions within portfolio
            matching_position  = next((position for position in portfolio.current_positions.values()
                                   if position._side == Side.BUY 
                                   and position._size == order._position._size 
                                   and position._price < order._position._price
                                   and position._date < order._position._date)
                                   ,None)
            
            if(matching_position != None):
                sale_earning = order._position._price * (order._position._size * STANDARD_LOT) 
                portfolio.add_to_wallet(sale_earning)
                portfolio.sell_position(matching_position)
                print(f"SELL ORDER FILLED : (ID) {str(order._id).upper()}")
            else:
                print("NO MATCHING POSITION FOUND")
    
    print("ALL ORDERS HAVE BEEN FILLED.")
    print("BOOK CASH LEVEL:", ("£%.2f" % portfolio.cash_wallet))
    
    pnl = portfolio.cash_wallet - INITIAL_WALLET_CASH 
    
    if(pnl < 0):
        print("TOTAL LOSS",("£%.2f" % abs(pnl)))
    else:
        print("TOTAL PROFIT",("£%.2f" % pnl))

local_backtest_strategy(data)
# Out:
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 85495785-A9F8-480A-9A8A-831E0B919530
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8D13709B-F54B-4CBD-8B72-516B078D17DB
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) C6813DC1-E1EA-4BE0-82F5-5A42BC3E3B8E
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 689294DB-4ACF-4841-A03D-4311547109C2
# SELL ORDER FILLED : (ID) DB986E1C-93A1-4526-AB22-98E0904E6387
# SELL ORDER FILLED : (ID) 67629F54-DF03-4C35-B08C-5F0BB2D8E488
# SELL ORDER FILLED : (ID) 31CE908A-C073-4313-AA4F-BF7227004691
# SELL ORDER FILLED : (ID) F669C0EF-8EE8-4226-87B3-ECAFC2770151
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 6CD4908D-BD8F-4A55-A6B6-0A84BA00D6B3
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 27C88A69-AC31-4F1F-B9E9-4B03690D03C3
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 61727B5B-5CD3-4C98-BF82-D1D5EFE683E1
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 9AD21538-6C5A-48B8-91F9-6C285B7648EB
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 46390A82-FE7F-4A76-9733-2269BB633359
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E0E8170D-FD35-46EE-A292-805BE63B9D84
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) B65CD1DB-13EC-4C09-A3A2-95012B59BFC4
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7A8E27BD-3F05-4A2C-BDB4-5775DF96748D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID)
# SELL ORDER FILLED : (ID) B12C9222-40CE-4E27-82BD-498A058CD3F9
# SELL ORDER FILLED : (ID) 9C724ED7-2D77-4AC1-9D0C-740061B33BC2
# SELL ORDER FILLED : (ID) FAB06928-3A0F-4593-911E-D8E15F363905
# SELL ORDER FILLED : (ID) 6E1431A2-EE92-4CFA-ABF9-CBC92FC3CF76
# SELL ORDER FILLED : (ID) D1F425D5-F0E4-4553-9EF5-9339727CEAE6
# SELL ORDER FILLED : (ID) B49AC84A-3DBB-4909-98BF-6809006F8B4B
# SELL ORDER FILLED : (ID) F6A1E168-9B3E-43DA-9F8A-A91B4AD7CC60
# SELL ORDER FILLED : (ID) D5087D10-DF07-437F-B7BE-D2EE846060F7
# SELL ORDER FILLED : (ID) F26BCF66-3356-489D-96BD-8A49F125A850
# SELL ORDER FILLED : (ID) DF8C3524-5208-4078-B84A-EF49B23EE519
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 52A1FDDD-D1D3-42F7-9816-43BFC909D3D3
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 0F49B135-368C-4B20-9A3F-7F4052835685
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) A0DA2749-6E0E-450D-B82D-90839B7FCE7D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 32B51432-04F8-4C9C-9653-DEEC8D09F4D9
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) AB933DA2-5725-4179-A72E-1F5AAA879D68
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) ACDF5C56-178F-49F9-9917-10B0A8E5B2E7
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) EEFDEF75-7C73-4D5C-AA32-FD46D197D2F8
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1FDB6879-BF71-4F56-A87B-A7F42EF9AC9B
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7DFC9A03-D706-4958-B745-657ADB9B37D2
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8A413344-0C81-4977-A231-8BAECD218451
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 2F2C9E13-68D3-49D2-BEA2-A08A3D5585DC
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F21BE735-13B2-4DE1-BD16-9344FB586F11
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E5223810-A00E-4F2A-AE69-89C40F15EDED
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D0FC8383-FCD1-42DB-906F-51B0630D3027
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8AFFBEF2-5992-4CBA-89E0-37A3E6F57D5C
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 0BA60D27-EA97-46BE-A831-70F9331ED7EB
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) BB4DD0E4-0B50-4C65-98DE-0A78275D1A9E
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) DA205E13-EAD3-4778-A836-A6D66D33CEA0
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) C26A6742-6CF5-4440-8C8E-19945F6985DF
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) EB2F2B11-49C0-44B4-AA84-BAFE0EE7F162
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D4B4BF80-EAC2-4EEF-A76F-F415B29E8F06
# BOOK CASH IS INSUFFICIENT
# BOOK CASH IS INSUFFICIENT
# BOOK CASH IS INSUFFICIENT
# BOOK CASH IS INSUFFICIENT
# BOOK CASH IS INSUFFICIENT
# SELL ORDER FILLED : (ID) E0FC0430-1177-49B7-96E5-35E0E60C348F
# SELL ORDER FILLED : (ID) CF373915-5CA8-45E7-96D2-DA4B12145E7A
# SELL ORDER FILLED : (ID) 3A557618-8CDD-4F87-B4D8-A506DE04EA83
# SELL ORDER FILLED : (ID) 84AE6DA1-A38E-4245-9D9E-7CBA7CDFA225
# SELL ORDER FILLED : (ID) CBF120E6-0D79-4284-86A7-35B076ED6812
# SELL ORDER FILLED : (ID) C6E29454-3324-426D-98F3-E0ABDC105FD6
# SELL ORDER FILLED : (ID) EBC7069C-1A08-4973-9291-ADAB69F07633
# SELL ORDER FILLED : (ID) 5F6DBCD6-7C06-43AA-A5A7-28FFD5B74084
# SELL ORDER FILLED : (ID) 231799E6-AE5D-45E1-BCD7-70251AFB93D7
# SELL ORDER FILLED : (ID) F2CC071E-2CE0-4B47-96A3-49764BDA4B89
# SELL ORDER FILLED : (ID) C97AE797-D911-4211-A1A2-8B439DFD92F6
# SELL ORDER FILLED : (ID) 2F58347B-D87D-4570-93F4-12E6367E375E
# SELL ORDER FILLED : (ID) E88912CE-EF4B-41BD-BD73-3163779A7C72
# SELL ORDER FILLED : (ID) 0F986A30-DD51-4C2F-AD47-E730FDF9F0FF
# SELL ORDER FILLED : (ID) D72AE0E7-DC82-436D-9F86-7AFDC62D7047
# SELL ORDER FILLED : (ID) C4ADC0CB-635F-4197-AD78-A85D63008355
# SELL ORDER FILLED : (ID) B65F6ADD-BF51-4E04-8BAD-DA47DF2B6097
# SELL ORDER FILLED : (ID) 50D77E71-EC1B-47AB-90EE-C728B6C0AF95
# SELL ORDER FILLED : (ID) D47117AE-DD04-449A-BADC-694AAF58EB5B
# SELL ORDER FILLED : (ID) 144DD746-B807-49A3-A59F-C140F7899740
# SELL ORDER FILLED : (ID) D23560E9-1075-43FA-9ED8-5C19BCE64BF4
# SELL ORDER FILLED : (ID) F93259FE-97F7-47C6-811E-12D26A52AB0B
# SELL ORDER FILLED : (ID) F6D914A9-9AFE-4E2B-B15C-5C1AD8E0F907
# SELL ORDER FILLED : (ID) BA161E93-770C-4FBB-BFD8-A675F22B88FF
# SELL ORDER FILLED : (ID) F1A1E389-75C4-44E4-8F64-B7D9BB332C98
# SELL ORDER FILLED : (ID) 12DA02A8-DB8D-4A1E-8561-AD5F70F7E958
# SELL ORDER FILLED : (ID) 18E0E6BF-5B0F-49A5-A211-73097BD1BE1C
# SELL ORDER FILLED : (ID) 9E335C6A-DEA3-4A13-97B6-4F73937C1A06
# SELL ORDER FILLED : (ID) D891D296-850F-427F-A20A-3B6F6A79377C
# SELL ORDER FILLED : (ID) DDB51B05-F492-4143-9CE0-CC85701863DA
# SELL ORDER FILLED : (ID) 3F102BE9-A7A2-42FA-98C1-04B2C0D0F2DD
# SELL ORDER FILLED : (ID) 6945FF13-25DA-4819-B5A5-0F821A83BB98
# SELL ORDER FILLED : (ID) 302A8AEE-703D-4C31-A5C6-AE431B5E8AD4
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 6320F10E-CE94-48C7-AA8D-C52F6F117C1E
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 6A85085D-DCFF-4507-A489-939DBF1267CE
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 92EA11DE-E8BB-4C60-8F63-FE54558432EF
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 5B2CFE0B-6249-4C52-B666-B3CF263C01E7
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 070C07BC-AE8F-4677-9479-41606B33C43A
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) AF90BCFE-BB28-4FE3-9B9D-51BF10E661A6
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 32AA5108-5A82-4A06-8E78-0030789F2512
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D6191D73-960E-4D9C-A038-47F6A143A930
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) B1A5BE78-C498-46D7-87E2-46AD7B0386E8
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) A758CA18-3459-4D5F-A05B-29EF120679A7
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 3AE00D0F-58CD-490A-A3D9-A2E17B5ED8C4
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D3306D68-98E1-41DE-AAF2-3FE35DEF9FA5
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7A5FEADA-6A67-476B-91F1-AB0A132A92DD
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7D56BEBF-B09F-4228-992B-948619A19695
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 0E27EE82-4C4B-43EC-A649-8E76B9513977
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) A9E82DD2-78EB-4331-A9F9-EBD65128D852
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 5437CF9B-DF41-4576-BC1A-7ED42E253FCB
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) C3685163-F6CC-4205-A2D6-9C42D8868547
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1C898E5F-E7DE-444C-AC4A-40E733C41B35
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E846BB8F-959C-499A-B3E2-62B2AA5D668B
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E63FA8ED-5FCC-48B1-B9D0-A7025CD1A3EA
# SELL ORDER FILLED : (ID) F73FA013-4118-4863-8E53-5FB71CFB3857
# SELL ORDER FILLED : (ID) 1B0F7AF6-407C-4BE1-996E-08F9BBD9FC77
# SELL ORDER FILLED : (ID) 85287F2B-283A-4170-9896-3FDD3772AB5F
# SELL ORDER FILLED : (ID) D5B414B3-28C6-4798-8C38-0BB34F574214
# SELL ORDER FILLED : (ID) 963D7022-273C-4D0E-B3A7-0BD33A0D1EEC
# SELL ORDER FILLED : (ID) F698719C-05D7-40CC-9B50-15F07AC5BBBF
# SELL ORDER FILLED : (ID) F2546BF9-67CA-4335-BED7-5F522C5EDCD4
# SELL ORDER FILLED : (ID) 2334DF1A-DA0C-4E19-9444-E36E2509B344
# SELL ORDER FILLED : (ID) BF1065E7-584B-4F4F-BAB9-9E0EB49E90BD
# SELL ORDER FILLED : (ID) DE7B2657-1684-40F9-9156-B1DDC4D8C5CF
# SELL ORDER FILLED : (ID) 00DB2C9F-7A3F-4216-92FF-81BBA7420338
# SELL ORDER FILLED : (ID) A9B6B588-86CA-4BFD-B63E-702379DFE39D
# SELL ORDER FILLED : (ID) 0521574C-F709-4BE1-8791-F95AE983B97C
# SELL ORDER FILLED : (ID) C874B5F0-7FA0-4485-9825-B2D317E057AB
# SELL ORDER FILLED : (ID) 87F1AF44-07A2-4E96-B4E9-A7F404F093AD
# SELL ORDER FILLED : (ID) 19C8E330-7D30-4C14-BB99-5833DC23824E
# SELL ORDER FILLED : (ID) E5657C2C-3055-4220-BFC2-9B39DFE8BAC6
# SELL ORDER FILLED : (ID) 22F771EB-1EAA-442E-99F9-23DC1B22BB2D
# SELL ORDER FILLED : (ID) 0E54D194-660A-4BF1-9A7B-8565900193D2
# SELL ORDER FILLED : (ID) 5BF6B2B3-CAFA-40AF-ABC5-E04F0CD0D963
# SELL ORDER FILLED : (ID) 5084EFB9-4A6C-4D09-AAA9-2E5A2FAE0E69
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D0DB82A4-670A-4AAA-A7FA-944A9942074F
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) DF6726E2-A48A-4719-A08D-E9999FC02C57
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F50F7157-E561-4FD1-B6D3-CFAF5F3D2F4A
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 68400F8E-5ED0-4EA2-9EB6-7B20AEA45B75
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1E0001E5-E07F-4EE1-B55E-29E9D36E04E1
# SELL ORDER FILLED : (ID) 85E7C2A2-87DE-47CC-A848-8E4D7A6F1787
# SELL ORDER FILLED : (ID) 3FE2248A-3F72-4583-BC9D-34EEC93A81E0
# SELL ORDER FILLED : (ID) F528D58A-6077-4BD9-84CA-2CA6BE27C3B3
# SELL ORDER FILLED : (ID) 9D4F3CF3-5D76-4B39-9264-9539268BEDD0
# SELL ORDER FILLED : (ID) 9CDE64AE-1118-470E-8E81-BC2BEAE396AF
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 
# SELL ORDER FILLED : (ID) DB9E6741-F030-42E1-ACEB-EC81DC93C3E1
# SELL ORDER FILLED : (ID) A8BE4B47-F070-4F4F-8BC6-D4059DF851EF
# SELL ORDER FILLED : (ID) 4D6FD7FB-E1DE-46EF-8661-3E190A90C447
# SELL ORDER FILLED : (ID) 528E9169-9D01-4721-B3ED-BB0131BFA4C2
# SELL ORDER FILLED : (ID) 70FCBD19-DD2C-4CCB-90C5-BE4404EC4ABF
# SELL ORDER FILLED : (ID) 153A2FC9-E5E3-41D2-AFA6-E7689D0F739F
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) EBC2B217-A27A-49C9-AFEF-51C033371469
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E46FBC9C-17C8-471C-A292-056221BD9418
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) FD27BA50-0856-4EA4-8367-16CDD349C3A9
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 246B0D10-5C07-4A59-89DA-1452E6AE84A8
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 5EC97F08-5227-40A6-9DCC-9EC6B9D6440B
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1FBC5CA8-5430-4BCF-A6DB-20D7951E3718
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 28D8BE1B-7620-4278-9B04-E279467D307D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E88AC42F-25E7-4FF0-8D87-4DC5BC46F113
# SELL ORDER FILLED : (ID) F8EA2446-E16C-4C3A-B8E4-ACA3DC4F11D4
# SELL ORDER FILLED : (ID) 19A7489D-D8AC-4962-835D-C3E5FC36D503
# SELL ORDER FILLED : (ID) 71A56B60-A723-488A-B646-73C7E678D8C7
# SELL ORDER FILLED : (ID) 39321B4A-D714-483A-B590-4EA3429BDBAE
# SELL ORDER FILLED : (ID) E2C9226F-5678-4DEE-BD47-6FBDC3EA0A1D
# SELL ORDER FILLED : (ID) 87635839-1B6D-4BC8-9686-D51FCA63E654
# SELL ORDER FILLED : (ID) C03675A2-F1DE-4B44-B2AA-D2DDF95F7B54
# SELL ORDER FILLED : (ID) F0778152-9404-4B55-8B89-B2EF9450E684
# SELL ORDER FILLED : (ID) 56D12E21-4A95-4870-9844-D0634A5641FC
# SELL ORDER FILLED : (ID) 5243B861-BA30-4118-97AC-E664F076A04A
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) C26E0159-74B2-455D-A2B3-490CA32A304D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 44C597AF-67EC-4E68-B8C8-5F705B8C9E7B
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 3C33BBA3-B805-4D82-9C3F-B385C826BD5A
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 50E3AAA8-B1F4-4800-A0E2-BE99079AF753
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) A909075F-E2F7-4020-AA9F-1F5B5FC09284
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 29419F94-850E-4EE6-85E8-FD9799F1F9D8
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E7A23E30-666A-4D18-89B2-8F3E027AEC73
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 3AB5CD2D-1329-4EA3-A25A-19CB2F1EA0D9
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 2DB01446-7BFA-4562-B9A8-AA325E9F8ED7
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) C986608A-D422-4B43-B6CA-8D55A724F76C
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E6086A60-8E32-4756-A9C3-5374D9778555
# SELL ORDER FILLED : (ID) D9891ECD-8CFA-4968-8F5F-811D12B69A91
# SELL ORDER FILLED : (ID) 47B0CF47-5501-4572-9F61-A3FBFAB6D3E5
# SELL ORDER FILLED : (ID) 55D8CF0B-3FD3-4607-922A-F5F70B12573B
# SELL ORDER FILLED : (ID) 2157E070-0AEB-43C0-99A2-3B1AEF91FA9E
# SELL ORDER FILLED : (ID) C2A33109-EB26-4592-A808-EF267962CB64
# SELL ORDER FILLED : (ID) 35801660-C679-4ADA-9DC4-C40272E8E665
# SELL ORDER FILLED : (ID) CBEFC2F4-2D98-4C2C-AE60-F8C93EE009D6
# SELL ORDER FILLED : (ID) 9467D9CF-58DD-4151-AFFA-FBD9FCF9F627
# SELL ORDER FILLED : (ID) 7E316CB9-B6FF-476E-BB01-1C1BAB7367B4
# SELL ORDER FILLED : (ID) F5BC19F8-D3EC-4EE0-B983-FC027DB5C90D
# SELL ORDER FILLED : (ID) 846C9CE0-AAFC-4323-BDA1-20923B782676
# SELL ORDER FILLED : (ID) 9FF0C4B9-1DEB-4DBA-97E8-CB1AD917DF1D
# SELL ORDER FILLED : (ID) 80DC67FF-B033-45EC-9FC5-0A6808EC91B6
# SELL ORDER FILLED : (ID) C98FE929-2388-4375-B9BD-5EAD5E3B1476
# SELL ORDER FILLED : (ID) 9D24E3B1-4366-4D1B-88BE-3F094DE1E1A1
# SELL ORDER FILLED : (ID) 07B7A580-5881-44A0-89A7-F93B21C6C1F2
# SELL ORDER FILLED : (ID) 381F933F-DA87-48A9-B3B3-45577AF7B5BC
# SELL ORDER FILLED : (ID) 1B6E1135-FBEC-4B80-B950-D28B71BA8D9A
# SELL ORDER FILLED : (ID) C3529948-504F-48DE-8AB0-1D811EE92C3C
# SELL ORDER FILLED : (ID) B354D013-0B65-42C0-9DE4-06C6A0614664
# SELL ORDER FILLED : (ID) DFDFA0F5-E105-40A5-BCB5-46AB5C9FC789
# SELL ORDER FILLED : (ID) 0AA9FB16-446C-4FEE-8EA0-31D652880642
# SELL ORDER FILLED : (ID) 49EE10CF-E758-404F-9011-CFB803657CC5
# SELL ORDER FILLED : (ID) 4E8734DB-92CB-4F48-8248-2131CB3B4A5B
# SELL ORDER FILLED : (ID) 0856E83B-4117-4F9F-AFF1-75138A1FC956
# SELL ORDER FILLED : (ID) CC5B9E93-D52C-4624-8858-D57FCB7B7A63
# SELL ORDER FILLED : (ID) CA01216D-31D6-4C4F-A556-541BEAEE1178
# SELL ORDER FILLED : (ID) E1D90EC4-D2FD-4723-A2FF-65DC86D5B327
# SELL ORDER FILLED : (ID) B8D0E3B5-38A6-48C6-BD26-1E49DA540AF6
# SELL ORDER FILLED : (ID) 9A018BA8-BA61-47F9-B4ED-ED4B7BC0CBA1
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# ALL ORDERS HAVE BEEN FILLED.
# BOOK CASH LEVEL: £5768510.10
# TOTAL PROFIT £768510.10

# %% [markdown]
# ## Data Analysis and Research
#
# You can include all of your data analysis and research under this section. Maybe some cool charts and formulas too?

# %%
plot = data[['Close', 'SMA20']].plot(label='GBP/USD',figsize=(32,16))
plot.set_ylabel("Price (GBP/USD)")
# Out:
# Text(0, 0.5, 'Price (GBP/USD)')

# %% [markdown]
# ## Risk Management
#
# You can include your risk management process and functions (code) under this section.

# %%
def risk_manager():
    pass
